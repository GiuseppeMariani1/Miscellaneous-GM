# %%
import os
github_raw_url = "https://raw.githubusercontent.com/amun0905/Effect-of-sampling-frequency-on-log-return-variance/refs/heads/main/Effect%20of%20sampling%20frequency%20on%20log%20return%20variance%20(1).ipynb"


notebook_name = github_raw_url.split("/")[-1]
if not notebook_name.endswith(".ipynb"):
    notebook_name += ".ipynb"

os.system(f'wget -O "{notebook_name}" "{github_raw_url}"')

get_ipython().run_line_magic("run", f'"{notebook_name}"')
# Out:
# (1006, 1)
# (5031, 1)
# Price    0.035286
# dtype: float64
# Price    0.039026
# dtype: float64
# Price    0.038657
# dtype: float64
# Price    0.038394
# dtype: float64

# %%
# !pip install arch
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.3/981.3 kB 41.4 MB/s eta 0:00:00
# ...
